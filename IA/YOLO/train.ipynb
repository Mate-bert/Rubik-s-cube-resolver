# %%
from ultralytics import YOLO

# Chargement du modèle existant
model = YOLO("yolo11n.pt")

# Reprise de l'entraînement sur un nouveau dataset
model.train(
    data="yolo_config2.yaml",           # chemin vers le fichier YAML du dataset
    epochs=200,                 # nombre d'époques
    imgsz=640,                  # taille des images
    batch=16,                   # taille de batch depend de la RAM de la machine
    name="rubiks_faces_seg",    # nom du projet
    project="runs",             # dossier de sortie
    verbose=True,                 # pour avoir les logs complets
    augment=True          # pour activer l'augmentation des données
)
# Out:
#     171/200         0G       1.62      1.246     0.8866        140        640: 100%|██████████| 3/3 [00:12<00:00,  4.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
#                    all         11         77       0.72      0.699      0.685      0.256
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     172/200         0G      1.647      1.263     0.8835        129        640: 100%|██████████| 3/3 [00:12<00:00,  4.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
#                    all         11         77      0.728       0.68      0.685      0.264
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     173/200         0G      1.546      1.099     0.8863        145        640: 100%|██████████| 3/3 [00:12<00:00,  4.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]
#                    all         11         77      0.728       0.68      0.685      0.264
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     174/200         0G      1.559      1.151     0.8793        129        640: 100%|██████████| 3/3 [00:12<00:00,  4.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
#                    all         11         77      0.737      0.666      0.682      0.259
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     175/200         0G       1.59      1.176     0.8769        116        640: 100%|██████████| 3/3 [00:12<00:00,  4.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
#                    all         11         77      0.769      0.663      0.706      0.263
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     176/200         0G      1.734      1.206     0.9134        117        640: 100%|██████████| 3/3 [00:12<00:00,  4.32s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
#                    all         11         77      0.801      0.684      0.724      0.265
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     177/200         0G      1.661      1.174     0.9158        114        640: 100%|██████████| 3/3 [00:14<00:00,  4.68s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
#                    all         11         77      0.801      0.684      0.724      0.265
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     178/200         0G       1.52      1.169     0.8936        106        640: 100%|██████████| 3/3 [00:13<00:00,  4.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
#                    all         11         77      0.802      0.688      0.726      0.272
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     179/200         0G      1.445      1.062     0.8836         85        640: 100%|██████████| 3/3 [00:12<00:00,  4.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]
#                    all         11         77      0.714      0.733        0.7      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     180/200         0G      1.495      1.138     0.8878        120        640: 100%|██████████| 3/3 [00:12<00:00,  4.26s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
#                    all         11         77      0.741      0.697      0.681      0.271
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     181/200         0G      1.655      1.185      0.908         98        640: 100%|██████████| 3/3 [00:13<00:00,  4.50s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
#                    all         11         77      0.741      0.697      0.681      0.271
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     182/200         0G      1.569      1.105     0.8844         97        640: 100%|██████████| 3/3 [00:13<00:00,  4.58s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
#                    all         11         77       0.74      0.697      0.682      0.274
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     183/200         0G      1.588      1.188     0.8754        127        640: 100%|██████████| 3/3 [00:13<00:00,  4.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
#                    all         11         77      0.704      0.719      0.682      0.268
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     184/200         0G      1.475      1.087     0.8772         80        640: 100%|██████████| 3/3 [00:13<00:00,  4.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
#                    all         11         77      0.762      0.712      0.718       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     185/200         0G       1.56      1.185     0.9138         93        640: 100%|██████████| 3/3 [00:12<00:00,  4.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
#                    all         11         77      0.762      0.712      0.718       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     186/200         0G      1.635      1.191     0.8906        111        640: 100%|██████████| 3/3 [00:12<00:00,  4.33s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
#                    all         11         77      0.774      0.715      0.723      0.272
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     187/200         0G      1.502      1.079     0.8698        115        640: 100%|██████████| 3/3 [00:13<00:00,  4.66s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
#                    all         11         77      0.759      0.751       0.75      0.277
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     188/200         0G      1.595      1.142     0.8812        126        640: 100%|██████████| 3/3 [00:13<00:00,  4.58s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.17s/it]
#                    all         11         77      0.765      0.698      0.714      0.269
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     189/200         0G      1.616      1.129     0.8908        118        640: 100%|██████████| 3/3 [00:13<00:00,  4.51s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.30s/it]
#                    all         11         77      0.765      0.698      0.714      0.269
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     190/200         0G      1.573      1.226     0.8706         89        640: 100%|██████████| 3/3 [00:13<00:00,  4.50s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
#                    all         11         77       0.78      0.719      0.731      0.275
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     191/200         0G      1.594      1.142     0.8997         77        640: 100%|██████████| 3/3 [00:13<00:00,  4.52s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
#                    all         11         77      0.765       0.71      0.706       0.27
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     192/200         0G      1.602      1.173     0.9161         77        640: 100%|██████████| 3/3 [00:13<00:00,  4.42s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]
#                    all         11         77      0.751      0.684      0.687      0.279
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     193/200         0G      1.543      1.103     0.9028         76        640: 100%|██████████| 3/3 [00:13<00:00,  4.56s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
#                    all         11         77      0.751      0.684      0.687      0.279
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     194/200         0G      1.507      1.137     0.8821         76        640: 100%|██████████| 3/3 [00:12<00:00,  4.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
#                    all         11         77       0.75      0.686      0.688      0.282
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     195/200         0G        1.5      1.093     0.8982         77        640: 100%|██████████| 3/3 [00:12<00:00,  4.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
#                    all         11         77      0.695      0.721      0.673      0.273
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     196/200         0G      1.503      1.093     0.9094         77        640: 100%|██████████| 3/3 [00:13<00:00,  4.49s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
#                    all         11         77      0.714      0.722      0.671      0.278
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     197/200         0G      1.476      1.044     0.9074         77        640: 100%|██████████| 3/3 [00:12<00:00,  4.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
#                    all         11         77      0.714      0.722      0.671      0.278
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     198/200         0G      1.448      1.031     0.8979         77        640: 100%|██████████| 3/3 [00:13<00:00,  4.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
#                    all         11         77      0.738      0.734      0.686      0.283
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     199/200         0G      1.458      1.048     0.8945         77        640: 100%|██████████| 3/3 [00:13<00:00,  4.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
#                    all         11         77      0.723      0.722      0.676      0.283
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     200/200         0G      1.485      1.132     0.9086         77        640: 100%|██████████| 3/3 [00:12<00:00,  4.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]
#                    all         11         77      0.723      0.722      0.675      0.281
# 200 epochs completed in 0.775 hours.
# Optimizer stripped from runs\rubiks_faces_seg6\weights\last.pt, 5.5MB
# Optimizer stripped from runs\rubiks_faces_seg6\weights\best.pt, 5.5MB
#
# Validating runs\rubiks_faces_seg6\weights\best.pt...
# Ultralytics 8.3.99  Python-3.12.5 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-12500T)
# YOLO11n summary (fused): 100 layers, 2,583,517 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.16s/it]
#                    all         11         77      0.743      0.692       0.71       0.28
#                      1         11         11      0.715      0.688      0.719      0.337
#                      2         11         11      0.805      0.818      0.835      0.323
#                      3         11         11       0.66      0.727      0.683      0.208
#                      4         11         11      0.678      0.545      0.582      0.215
#                      5         11         11      0.844      0.727       0.78      0.353
#                      6         11         11      0.611      0.636      0.529      0.188
#                 centre         11         11      0.885      0.705      0.842      0.336
# Speed: 1.6ms preprocess, 186.0ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs\rubiks_faces_seg6
# Ultralytics 8.3.99  Python-3.12.5 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-12500T)
# YOLO11n summary (fused): 100 layers, 2,583,517 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning C:\Users\gnsakawakatamba\Documents\Perso\ecole\Rubik-s-cube-resolver\IA\YOLO\dataset\valid\labels.cache... 11 images, 0 backgrounds, 0 corrupt: 100%|██████████| 11/11 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.83s/it]
#                    all         11         77      0.743      0.692       0.71       0.28
#                      1         11         11      0.715      0.688      0.719      0.337
#                      2         11         11      0.805      0.818      0.835      0.323
#                      3         11         11       0.66      0.727      0.683      0.208
#                      4         11         11      0.678      0.545      0.582      0.215
#                      5         11         11      0.844      0.727       0.78      0.353
#                      6         11         11      0.611      0.636      0.529      0.188
#                 centre         11         11      0.885      0.705      0.842      0.336
# Speed: 1.3ms preprocess, 156.1ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs\rubiks_faces_seg62

# %%
# 3. Visualisation des résultats
import os
from IPython.display import Image, display

# Chemin vers le fichier de résultats
result_img_path = os.path.join("runs", "rubiks_faces_seg6", "results.png")

# Affichage de l'image
display(Image(filename=result_img_path))

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import os

# Chemin du modèle entraîné et de l'image
model = YOLO("runs/rubiks_faces_seg5/weights/best.pt")
img_path = "./../../data/raw/3face_1.jpg"

# Prédiction
results = model.predict(source=img_path, save=False, imgsz=640, conf=0.25)
detected = results[0]

# Affichage des infos
print("Nombre de détections :", len(detected.boxes))
for box in detected.boxes:
    cls = int(box.cls[0])
    conf = float(box.conf[0])
    print(f"Classe : {detected.names[cls]}, Confiance : {conf:.2f}")

# Sauvegarde de l'image annotée
annotated_img = detected.plot()
save_path = "predicted.jpg"
cv2.imwrite(save_path, annotated_img)
print(f"Image annotée sauvegardée dans : {save_path}")
# Out:
# image 1/1 c:\Users\gnsakawakatamba\Documents\Perso\ecole\Rubik-s-cube-resolver\IA\YOLO\..\..\data\raw\3face_1.jpg: 640x640 1 1, 1 2, 1 3, 1 4, 2 5s, 1 6, 2 centres, 71.2ms
# Speed: 2.9ms preprocess, 71.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Nombre de détections : 9
# Classe : 3, Confiance : 0.73
# Classe : 5, Confiance : 0.64
# Classe : 2, Confiance : 0.47
# Classe : centre, Confiance : 0.47
# Classe : 1, Confiance : 0.45
# Classe : 6, Confiance : 0.40
# Classe : centre, Confiance : 0.31
# Classe : 5, Confiance : 0.29
# Classe : 4, Confiance : 0.25
# Image annotée sauvegardée dans : predicted.jpg

# %%
model = YOLO("runs/rubiks_faces_seg5/weights/best.pt")
path = model.export(format="onnx")
# Out:
# Ultralytics 8.3.99  Python-3.12.5 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-12500T)
# YOLO11n summary (fused): 100 layers, 2,583,517 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'runs\rubiks_faces_seg5\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 11, 8400) (5.2 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# Defaulting to user installation because normal site-packages is not writeable
# Collecting onnx>=1.12.0
#   Downloading onnx-1.17.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting onnxslim
#   Downloading onnxslim-0.1.50-py3-none-any.whl.metadata (4.8 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.21.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\gnsakawakatamba\appdata\roaming\python\python312\site-packages (from onnx>=1.12.0) (2.0.2)
# Requirement already satisfied: protobuf>=3.20.2 in c:\users\gnsakawakatamba\appdata\roaming\python\python312\site-packages (from onnx>=1.12.0) (5.28.3)
# Requirement already satisfied: sympy in c:\users\gnsakawakatamba\appdata\roaming\python\python312\site-packages (from onnxslim) (1.13.1)
# Requirement already satisfied: packaging in c:\users\gnsakawakatamba\appdata\roaming\python\python312\site-packages (from onnxslim) (24.1)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\gnsakawakatamba\appdata\roaming\python\python312\site-packages (from sympy->onnxslim) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Downloading onnx-1.17.0-cp312-cp312-win_amd64.whl (14.5 MB)
#    ---------------------------------------- 14.5/14.5 MB 65.2 MB/s eta 0:00:00
# Downloading onnxslim-0.1.50-py3-none-any.whl (144 kB)
# Downloading onnxruntime-1.21.0-cp312-cp312-win_amd64.whl (11.8 MB)
#    ---------------------------------------- 11.8/11.8 MB 36.7 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: flatbuffers, pyreadline3, onnx, onnxslim, humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 flatbuffers-25.2.10 humanfriendly-10.0 onnx-1.17.0 onnxruntime-1.21.0 onnxslim-0.1.50 pyreadline3-3.5.4
#
# requirements: AutoUpdate success  13.1s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.50...
# ONNX: export success  14.5s, saved as 'runs\rubiks_faces_seg5\weights\best.onnx' (10.1 MB)
#
# Export complete (14.8s)
# Results saved to C:\Users\gnsakawakatamba\Documents\Perso\ecole\Rubik-s-cube-resolver\IA\YOLO\runs\rubiks_faces_seg5\weights
# Predict:         yolo predict task=detect model=runs\rubiks_faces_seg5\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\rubiks_faces_seg5\weights\best.onnx imgsz=640 data=yolo_config2.yaml
# Visualize:       https://netron.app
